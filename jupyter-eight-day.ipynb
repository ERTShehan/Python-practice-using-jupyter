# %% [markdown]
# # Web Scraping

# %% [markdown]
# Request Library

# %%
import requests

response = requests.get('https://api.github.com/events')
print(response)
print(type(response))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %%
print(response.status_code)
# 200 means success
# 404 means not found
# 500 means server error
# 403 means forbidden not allowed

if response.status_code == 200:
    print("Success")
else:
    print("Error occurred")
# Out:
# 200
# Success

# %%
print(response.headers)
print(response.headers['Content-Type'])
print(response.text) # return JSON array

# content eka json ekak widiyata return karannawa nam dictnory ekak widiyata ganna puluwan
# dictionary ekak widiyata anne thani json ekak thiyenawanam
# mekedi json array ekak thiyena nisa list ekak widiyata gannawa
print(response.json())
print(type(response.json()))  # list
print(response.json()[0]['type'])
# Out:
# {'Date': 'Fri, 13 Feb 2026 10:24:59 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=300, s-maxage=300', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"c4357570e1ae4108ebf2d4adda622b0ee5ca547cf7fbca7c373b34c9c7c0acac"', 'Last-Modified': 'Fri, 13 Feb 2026 10:19:58 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1770981899', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': '39E2:CC958:2C074:3235B:698EFBF9'}
# application/json; charset=utf-8
# [{"id":"8415094888","type":"PushEvent","actor":{"id":217094273,"login":"thisisshantu","display_login":"thisisshantu","gravatar_id":"","url":"https://api.github.com/users/thisisshantu","avatar_url":"https://avatars.githubusercontent.com/u/217094273?"},"repo":{"id":1150351673,"name":"thisisshantu/portfolio-assets","url":"https://api.github.com/repos/thisisshantu/portfolio-assets"},"payload":{"repository_id":1150351673,"push_id":30710060625,"ref":"refs/heads/main","head":"3bea4b6229e254be0dc3a4f9bc755ec2e33228ca","before":"f78ed8639e1d1f9ece7be9ecf835011a06f0f449"},"public":true,"created_at":"2026-02-13T10:19:58Z"},{"id":"8415094830","type":"PushEvent","actor":{"id":229729431,"login":"rahimahangarzadeh","display_login":"rahimahangarzadeh","gravatar_id":"","url":"https://api.github.com/users/rahimahangarzadeh","avatar_url":"https://avatars.githubusercontent.com/u/229729431?"},"repo":{"id":1156973233,"name":"rahimahangarzadeh/GFMagazinWerkstatt","url":"https://api.github.com/repos/rahimahangarzadeh/GFMagazinWerkstatt"},"payload":{"repository_id":1156973233,"push_id":30710060548,"ref":"refs/heads/main","head":"248ca553087007480e85db1c0621e37a030c5da9","before":"72b55844f19802024035901bee77259829b96672"},"public":true,"created_at":"2026-02-13T10:19:58Z"},{"id":"8415094654","type":"PushEvent","actor":{"id":99170465,"login":"hannuverma","display_login":"hannuverma","gravatar_id":"","url":"https://api.github.com/users/hannuverma","avatar_url":"https://avatars.githubusercontent.com/u/99170465?"},"repo":{"id":1149947972,"name":"hannuverma/ResolveIt","url":"https://api.github.com/repos/hannuverma/ResolveIt"},"payload":{"repository_id":1149947972,"push_id":30710060357,"ref":"refs/heads/main","head":"5a0c7cd68b5c7b25cfb2b9e0e4b1f317193c8674","before":"3c6e13bdf9c9ec099330948d5f8659113f340333"},"public":true,"created_at":"2026-02-13T10:19:58Z"},{"id":"8415094662","type":"PushEvent","actor":{"id":4881477,"login":"edalcin","display_login":"edalcin","gravatar_id":"","url":"https://api.github.com/users/edalcin","avatar_url":"https://avatars.githubusercontent.com/u/4881477?"},"repo":{"id":1152139277,"name":"edalcin/smartLattes","url":"https://api.github.com/repos/edalcin/smartLattes"},"payload":{"repository_id":1152139277,"push_id":30710060381,"ref":"refs/heads/main","head":"6386f00ae82b19062148950909568e7a5a0f11f5","before":"5d64dcbc3d43d86a6dd0eb4b96521a2e54506def"},"public":true,"created_at":"2026-02-13T10:19:58Z"},{"id":"8415094668","type":"CreateEvent","actor":{"id":166895733,"login":"swa-runner-app[bot]","display_login":"swa-runner-app","gravatar_id":"","url":"https://api.github.com/users/swa-runner-app[bot]","avatar_url":"https://avatars.githubusercontent.com/u/166895733?"},"repo":{"id":1157012838,"name":"static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286","url":"https://api.github.com/repos/static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286"},"payload":{"ref":"main","ref_type":"branch","full_ref":"refs/heads/main","master_branch":"main","description":"swacd5f04db9be843198f06b2b547b38286","pusher_type":"user"},"public":true,"created_at":"2026-02-13T10:19:58Z","org":{"id":96167003,"login":"static-web-apps-testing-org","gravatar_id":"","url":"https://api.github.com/orgs/static-web-apps-testing-org","avatar_url":"https://avatars.githubusercontent.com/u/96167003?"}},{"id":"8415094671","type":"PushEvent","actor":{"id":244841556,"login":"escapingwork","display_login":"escapingwork","gravatar_id":"","url":"https://api.github.com/users/escapingwork","avatar_url":"https://avatars.githubusercontent.com/u/244841556?"},"repo":{"id":1099385184,"name":"escapingwork/teenagerspopulation","url":"https://api.github.com/repos/escapingwork/teenagerspopulation"},"payload":{"repository_id":1099385184,"push_id":30710060391,"ref":"refs/heads/main","head":"168202c6fa171b3539641620454ed5f680bbfe1c","before":"162e0f57747b0e2decea08fc2441a67e35807eeb"},"public":true,"created_at":"2026-02-13T10:19:58Z"},{"id":"8415094680","type":"PushEvent","a ...
# [{'id': '8415094888', 'type': 'PushEvent', 'actor': {'id': 217094273, 'login': 'thisisshantu', 'display_login': 'thisisshantu', 'gravatar_id': '', 'url': 'https://api.github.com/users/thisisshantu', 'avatar_url': 'https://avatars.githubusercontent.com/u/217094273?'}, 'repo': {'id': 1150351673, 'name': 'thisisshantu/portfolio-assets', 'url': 'https://api.github.com/repos/thisisshantu/portfolio-assets'}, 'payload': {'repository_id': 1150351673, 'push_id': 30710060625, 'ref': 'refs/heads/main', 'head': '3bea4b6229e254be0dc3a4f9bc755ec2e33228ca', 'before': 'f78ed8639e1d1f9ece7be9ecf835011a06f0f449'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094830', 'type': 'PushEvent', 'actor': {'id': 229729431, 'login': 'rahimahangarzadeh', 'display_login': 'rahimahangarzadeh', 'gravatar_id': '', 'url': 'https://api.github.com/users/rahimahangarzadeh', 'avatar_url': 'https://avatars.githubusercontent.com/u/229729431?'}, 'repo': {'id': 1156973233, 'name': 'rahimahangarzadeh/GFMagazinWerkstatt', 'url': 'https://api.github.com/repos/rahimahangarzadeh/GFMagazinWerkstatt'}, 'payload': {'repository_id': 1156973233, 'push_id': 30710060548, 'ref': 'refs/heads/main', 'head': '248ca553087007480e85db1c0621e37a030c5da9', 'before': '72b55844f19802024035901bee77259829b96672'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094654', 'type': 'PushEvent', 'actor': {'id': 99170465, 'login': 'hannuverma', 'display_login': 'hannuverma', 'gravatar_id': '', 'url': 'https://api.github.com/users/hannuverma', 'avatar_url': 'https://avatars.githubusercontent.com/u/99170465?'}, 'repo': {'id': 1149947972, 'name': 'hannuverma/ResolveIt', 'url': 'https://api.github.com/repos/hannuverma/ResolveIt'}, 'payload': {'repository_id': 1149947972, 'push_id': 30710060357, 'ref': 'refs/heads/main', 'head': '5a0c7cd68b5c7b25cfb2b9e0e4b1f317193c8674', 'before': '3c6e13bdf9c9ec099330948d5f8659113f340333'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094662', 'type': 'PushEvent', 'actor': {'id': 4881477, 'login': 'edalcin', 'display_login': 'edalcin', 'gravatar_id': '', 'url': 'https://api.github.com/users/edalcin', 'avatar_url': 'https://avatars.githubusercontent.com/u/4881477?'}, 'repo': {'id': 1152139277, 'name': 'edalcin/smartLattes', 'url': 'https://api.github.com/repos/edalcin/smartLattes'}, 'payload': {'repository_id': 1152139277, 'push_id': 30710060381, 'ref': 'refs/heads/main', 'head': '6386f00ae82b19062148950909568e7a5a0f11f5', 'before': '5d64dcbc3d43d86a6dd0eb4b96521a2e54506def'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094668', 'type': 'CreateEvent', 'actor': {'id': 166895733, 'login': 'swa-runner-app[bot]', 'display_login': 'swa-runner-app', 'gravatar_id': '', 'url': 'https://api.github.com/users/swa-runner-app[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'}, 'repo': {'id': 1157012838, 'name': 'static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286', 'url': 'https://api.github.com/repos/static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'full_ref': 'refs/heads/main', 'master_branch': 'main', 'description': 'swacd5f04db9be843198f06b2b547b38286', 'pusher_type': 'user'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z', 'org': {'id': 96167003, 'login': 'static-web-apps-testing-org', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/static-web-apps-testing-org', 'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}}, {'id': '8415094671', 'type': 'PushEvent', 'actor': {'id': 244841556, 'login': 'escapingwork', 'display_login': 'escapingwork', 'gravatar_id': '', 'url': 'https://api.github.com/users/escapingwork', 'avatar_url': 'https://avatars.githubusercontent.com/u/244841556?'}, 'repo': {'id': 1099385184, 'name': 'escapingwork/teenagerspopulation', 'url': 'https://api.github.com/repos/escapingwork/teenagerspopulation'}, 'payload': {'repository_id': 1099385184, 'push ...
# <class 'list'>
# PushEvent

# %%
# if response.headers['Content-Type'] == 'application/json'
# meka use karana wita charset=utf-8 da athulath wiya yuthuya. content type ekedi akath return wenawa.

if 'application/json' in response.headers.get('Content-Type', ''):
    data = response.json()
    print("JSON data received")
    print(data)
# Out:
# JSON data received
# [{'id': '8415094888', 'type': 'PushEvent', 'actor': {'id': 217094273, 'login': 'thisisshantu', 'display_login': 'thisisshantu', 'gravatar_id': '', 'url': 'https://api.github.com/users/thisisshantu', 'avatar_url': 'https://avatars.githubusercontent.com/u/217094273?'}, 'repo': {'id': 1150351673, 'name': 'thisisshantu/portfolio-assets', 'url': 'https://api.github.com/repos/thisisshantu/portfolio-assets'}, 'payload': {'repository_id': 1150351673, 'push_id': 30710060625, 'ref': 'refs/heads/main', 'head': '3bea4b6229e254be0dc3a4f9bc755ec2e33228ca', 'before': 'f78ed8639e1d1f9ece7be9ecf835011a06f0f449'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094830', 'type': 'PushEvent', 'actor': {'id': 229729431, 'login': 'rahimahangarzadeh', 'display_login': 'rahimahangarzadeh', 'gravatar_id': '', 'url': 'https://api.github.com/users/rahimahangarzadeh', 'avatar_url': 'https://avatars.githubusercontent.com/u/229729431?'}, 'repo': {'id': 1156973233, 'name': 'rahimahangarzadeh/GFMagazinWerkstatt', 'url': 'https://api.github.com/repos/rahimahangarzadeh/GFMagazinWerkstatt'}, 'payload': {'repository_id': 1156973233, 'push_id': 30710060548, 'ref': 'refs/heads/main', 'head': '248ca553087007480e85db1c0621e37a030c5da9', 'before': '72b55844f19802024035901bee77259829b96672'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094654', 'type': 'PushEvent', 'actor': {'id': 99170465, 'login': 'hannuverma', 'display_login': 'hannuverma', 'gravatar_id': '', 'url': 'https://api.github.com/users/hannuverma', 'avatar_url': 'https://avatars.githubusercontent.com/u/99170465?'}, 'repo': {'id': 1149947972, 'name': 'hannuverma/ResolveIt', 'url': 'https://api.github.com/repos/hannuverma/ResolveIt'}, 'payload': {'repository_id': 1149947972, 'push_id': 30710060357, 'ref': 'refs/heads/main', 'head': '5a0c7cd68b5c7b25cfb2b9e0e4b1f317193c8674', 'before': '3c6e13bdf9c9ec099330948d5f8659113f340333'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094662', 'type': 'PushEvent', 'actor': {'id': 4881477, 'login': 'edalcin', 'display_login': 'edalcin', 'gravatar_id': '', 'url': 'https://api.github.com/users/edalcin', 'avatar_url': 'https://avatars.githubusercontent.com/u/4881477?'}, 'repo': {'id': 1152139277, 'name': 'edalcin/smartLattes', 'url': 'https://api.github.com/repos/edalcin/smartLattes'}, 'payload': {'repository_id': 1152139277, 'push_id': 30710060381, 'ref': 'refs/heads/main', 'head': '6386f00ae82b19062148950909568e7a5a0f11f5', 'before': '5d64dcbc3d43d86a6dd0eb4b96521a2e54506def'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z'}, {'id': '8415094668', 'type': 'CreateEvent', 'actor': {'id': 166895733, 'login': 'swa-runner-app[bot]', 'display_login': 'swa-runner-app', 'gravatar_id': '', 'url': 'https://api.github.com/users/swa-runner-app[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/166895733?'}, 'repo': {'id': 1157012838, 'name': 'static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286', 'url': 'https://api.github.com/repos/static-web-apps-testing-org/swacd5f04db9be843198f06b2b547b38286'}, 'payload': {'ref': 'main', 'ref_type': 'branch', 'full_ref': 'refs/heads/main', 'master_branch': 'main', 'description': 'swacd5f04db9be843198f06b2b547b38286', 'pusher_type': 'user'}, 'public': True, 'created_at': '2026-02-13T10:19:58Z', 'org': {'id': 96167003, 'login': 'static-web-apps-testing-org', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/static-web-apps-testing-org', 'avatar_url': 'https://avatars.githubusercontent.com/u/96167003?'}}, {'id': '8415094671', 'type': 'PushEvent', 'actor': {'id': 244841556, 'login': 'escapingwork', 'display_login': 'escapingwork', 'gravatar_id': '', 'url': 'https://api.github.com/users/escapingwork', 'avatar_url': 'https://avatars.githubusercontent.com/u/244841556?'}, 'repo': {'id': 1099385184, 'name': 'escapingwork/teenagerspopulation', 'url': 'https://api.github.com/repos/escapingwork/teenagerspopulation'}, 'payload': {'repository_id': 1099385184, 'push ...

# %%
import requests

response = requests.get('https://api.github.com/events')
print(response)

if response.status_code == 200:
    print(response.text[:100])
else:
    print("Failed to retrieve data" ,response.status_code)
# Out:
# <Response [200]>
# [{"id":"8415147730","type":"PushEvent","actor":{"id":5515111,"login":"onesoftuk","display_login":"on

# %%
# POST

import requests

# data to be sent in the from
data = {'username': 'user', 'password': 'pass'}
# URL where the form should be submitted
response = requests.post('https://httpbin.org/post', data)

if response.status_code == 200:
    print("Form submitted successfully")
    print(response.text)
else:
    print("Failed to submit form", response.status_code)
# Out:
# Form submitted successfully
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-698efe82-06d091c1351f3ee310148ef2"
#   },
#   "json": null,
#   "origin": "175.157.137.7",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# URL Parameters

# %%
import requests

url = "https://jsonplaceholder.typicode.com/posts"
params = {'userId': '1', 'id': 2}
response = requests.get(url, params=params)

print("Requested URL:", response.url)
print(response.text)
# Out:
# Requested URL: https://jsonplaceholder.typicode.com/posts?userId=1&id=2
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]

# %% [markdown]
# Basic Authentication

# %%
import requests

url = 'https://httpbin.org/get'
username = 'user'
password = 'pass'

response = requests.get(url, auth=(username, password))
# Check if the request was successful

if response.status_code == 200:
    print("Authenticated successfully")
    print(response.text)
else:
    print("Authentication failed", response.status_code)
# Out:
# Authenticated successfully
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.5",
#     "X-Amzn-Trace-Id": "Root=1-698f00bd-2c75fb82442c884e4a462c32"
#   },
#   "origin": "175.157.137.7",
#   "url": "https://httpbin.org/get"
# }

# %% [markdown]
# Beautiful Soup Library

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie; class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie; class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie; class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>
<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.title)

print(soup.a)
print(soup.p)
print(soup.find_all('a'))
# print(soup.find)
# Out:
# <title>The Dormouse's story</title>
# <a href="http://example.com/elsie; class=" id="link1" sister"="">Elsie</a>
# <p class="title"><b>The Dormouse's story</b></p>
# [<a href="http://example.com/elsie; class=" id="link1" sister"="">Elsie</a>, <a href="http://example.com/lacie; class=" id="link2" sister"="">Lacie</a>, <a href="http://example.com/tillie; class=" id="link3" sister"="">Tillie</a>]

# %% [markdown]
# Q. Fetch a webpage, check if the request was successful, and extract the main heading text from the page's content. You can assume that the base url is 'http://example.com'.

# %%
import requests

url = 'http://example.com'
response = requests.get(url)

if response.status_code == 200:
    print("Request was successful")
    # print(response.text)
    soup = BeautifulSoup(response.text, 'html.parser')
    h1_tag = soup.find('h1')

    if h1_tag:
        print(h1_tag.text)
    else:
        print("No <h1> tag found")
else:
    print("Request failed: ", response.status_code)
# Out:
# Request was successful
# Example Domain

# %% [markdown]
# # API Integration

# %%
import requests

url = 'https://api.open-meteo.com/v1/forecast'

params = {
    "latitude": 6.0375,
    "longitude": 80.2076,
    "current": "temperature_2m,windspeed_10m",
}

response = requests.get(url, params=params)
if response.status_code == 200:
    print("Weather data retrieved successfully")
    print(response.headers.get('Content-Type'))
    weather_data = response.json()

    if weather_data and 'current' in weather_data:
        print(f"temperature_2m: {weather_data['current']['temperature_2m']}")
        print(f"windspeed_10m: {weather_data['current']['windspeed_10m']}")
    else:
        print("No current weather data found")
        
else:
    print("Failed to retrieve data", response.status_code)
# Out:
# Weather data retrieved successfully
# application/json; charset=utf-8
# temperature_2m: 27.8
# windspeed_10m: 6.4

# %% [markdown]
# # Python Error Type

# %% [markdown]
# * Syntax error
# * Runtime error
# * Loical error

# %% [markdown]
# # Python Debugger (pdb)

# %%
import pdb

print("Starting")
x = 5
pdb.set_trace()
y = 0

z = x / y
print("Finished")
# Out:
# Starting
# > c:\users\shehan\appdata\local\temp\ipykernel_940\13252079.py(5)<module>()
# *** NameError: name 'we' is not defined
# 5
# 0
# 58
# 58
